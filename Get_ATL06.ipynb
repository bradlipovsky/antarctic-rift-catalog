# %%
import os
import shutil
import h5py
import matplotlib.pyplot as plt
from icepyx import icesat2data as ipd

# %%
short_name = 'ATL06'
spatial_extent = [-26.5, -75.8, -24.5, -75.3]
date_range = ['2018-10-14','2020-04-4']
region_a = ipd.Icesat2Data(short_name, spatial_extent, date_range)

earthdata_uid = 'therealbradlipovsky'
email = 'brad_lipovsky@fas.harvard.edu'
region_a.earthdata_login(earthdata_uid, email)
# Out:
# Earthdata Login password: ········

# %%
region_a.download_granules('/Users/bradlipovsky/is2-data/')
# Out:
# Total number of data order requests is  13  for  130  granules.
# Data request  1  of  13  is submitting to NSIDC
# order ID:  5000000711901
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['177219209:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '177245142:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '177248709:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.191S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  2  of  13  is submitting to NSIDC
# order ID:  5000000711903
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['177219833:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '177225663:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '177692600:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.651S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  3  of  13  is submitting to NSIDC
# order ID:  5000000711905
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['177979602:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '177542141:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT8.122S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  4  of  13  is submitting to NSIDC
# order ID:  5000000711906
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['177545821:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178005968:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178011345:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.503S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  5  of  13  is submitting to NSIDC
# order ID:  5000000711908
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178005890:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178026417:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178026661:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178025203:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT9.886S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  6  of  13  is submitting to NSIDC
# order ID:  5000000711909
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178041536:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178070277:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.500S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  7  of  13  is submitting to NSIDC
# order ID:  5000000711911
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178119682:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178104300:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178138881:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.780S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  8  of  13  is submitting to NSIDC
# order ID:  5000000711913
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178183128:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.375S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  9  of  13  is submitting to NSIDC
# order ID:  5000000711915
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178173359:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178240159:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178245255:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178348849:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.627S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  10  of  13  is submitting to NSIDC
# order ID:  5000000711917
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['179010189:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT9.091S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  11  of  13  is submitting to NSIDC
# order ID:  5000000711918
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['179019765:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178977966:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178936207:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.706S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  12  of  13  is submitting to NSIDC
# order ID:  5000000711920
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['178937872:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '179085875:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '178938566:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT7.526S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Data request  13  of  13  is submitting to NSIDC
# order ID:  5000000711922
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order is:  complete_with_errors
# NSIDC provided these error messages:
# ['180682268:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '180676602:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  '180681375:NoMatchingData - No data found that matched subset constraints. '
#  'Exit code 3.',
#  'PT8.167S',
#  'ICESAT2']
# Your order is: complete_with_errors
# Beginning download of zipped output...
# Data request 5000000711901 of  13  order(s) is downloaded.
# Beginning download of zipped output...
# Data request 5000000711903 of  13  order(s) is downloaded.
# Beginning download of zipped output...
# Data request 5000000711905 of  13  order(s) is downloaded.
# Beginning download of zipped output...
# Data request 5000000711906 of  13  order(s) is downloaded.
# Beginning download of zipped output...
# Data request 5000000711908 of  13  order(s) is downloaded.
# Beginning download of zipped output...
# Data request 5000000711909 of  13  order(s) is downloaded.
# Beginning download of zipped output...
